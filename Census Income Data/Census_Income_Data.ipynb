# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv(r"C:\Users\91830\Downloads\census_income_data.csv")

# %%
dataset.columns
# Out:
# Index(['AAGE', 'ACLSWKR', 'ADTINK', 'ADTOCC', 'AHGA', 'AHSCOL', 'AMARITL',
#        'AMJIND', 'AMJOCC', 'ARACE', 'AREORGN', 'ASEX', 'AUNMEM', 'AUNTYPE',
#        'AWKSTAT', 'CAPGAIN', 'GAPLOSS', 'DIVVAL', 'FILESTAT', 'GRINREG',
#        'GRINST', 'HHDFMX', 'HHDREL', 'MARSUPWRT', 'MIGMTR1', 'MIGMTR3',
#        'MIGMTR4', 'MIGSAME', 'MIGSUN', 'NOEMP', 'PARENT', 'PEFNTVTY',
#        'PEMNTVTY', 'PENATVTY', 'PRCITSHP', 'SEOTR', 'VETQVA', 'VETYN',
#        'WKSWORK', 'AHRSPAY', 'year', 'income_bracket'],
#       dtype='object')

# %%
dataset.head()
# Out:
#    AAGE                          ACLSWKR  ADTINK  ADTOCC  \
# 0    73                  Not in universe       0       0
# 1    58   Self-employed-not incorporated       4      34
# 2    18                  Not in universe       0       0
# 3     9                  Not in universe       0       0
# 4    10                  Not in universe       0       0
#
#                           AHGA            AHSCOL         AMARITL  \
# 0         High school graduate   Not in universe         Widowed
# 1   Some college but no degree   Not in universe        Divorced
# 2                   10th grade       High school   Never married
# 3                     Children   Not in universe   Never married
# 4                     Children   Not in universe   Never married
#
#                          AMJIND                                AMJOCC  \
# 0   Not in universe or children                       Not in universe
# 1                  Construction   Precision production craft & repair
# ...

# %%
dataset.shape
# Out:
# (199523, 42)

# %%
dataset.isnull()
# Out:
#          AAGE  ACLSWKR  ADTINK  ADTOCC   AHGA  AHSCOL  AMARITL  AMJIND  \
# 0       False    False   False   False  False   False    False   False
# 1       False    False   False   False  False   False    False   False
# 2       False    False   False   False  False   False    False   False
# 3       False    False   False   False  False   False    False   False
# 4       False    False   False   False  False   False    False   False
# ...       ...      ...     ...     ...    ...     ...      ...     ...
# 199518  False    False   False   False  False   False    False   False
# 199519  False    False   False   False  False   False    False   False
# 199520  False    False   False   False  False   False    False   False
# 199521  False    False   False   False  False   False    False   False
# 199522  False    False   False   False  False   False    False   False
#
#         AMJOCC  ARACE  ...  PEMNTVTY  PENATVTY  PRCITSHP  SEOTR  VETQVA  \
# ...

# %%
dataset.isnull().sum()
# Out:
# AAGE                  0
# ACLSWKR               0
# ADTINK                0
# ADTOCC                0
# AHGA                  0
# AHSCOL                0
# AMARITL               0
# AMJIND                0
# AMJOCC                0
# ARACE                 0
# AREORGN               0
# ASEX                  0
# AUNMEM                0
# AUNTYPE               0
# AWKSTAT               0
# CAPGAIN               0
# GAPLOSS               0
# DIVVAL                0
# FILESTAT              0
# GRINREG               0
# GRINST              708
# HHDFMX                0
# HHDREL                0
# MARSUPWRT             0
# MIGMTR1           99696
# MIGMTR3           99696
# MIGMTR4           99696
# MIGSAME               0
# MIGSUN            99696
# NOEMP                 0
# PARENT                0
# PEFNTVTY           6713
# PEMNTVTY           6119
# PENATVTY           3393
# PRCITSHP              0
# SEOTR                 0
# VETQVA                0
# VETYN                 0
# ...

# %%
dataset.fillna(value=0, inplace=True)

# %%
dataset.isnull().sum()
# Out:
# AAGE              0
# ACLSWKR           0
# ADTINK            0
# ADTOCC            0
# AHGA              0
# AHSCOL            0
# AMARITL           0
# AMJIND            0
# AMJOCC            0
# ARACE             0
# AREORGN           0
# ASEX              0
# AUNMEM            0
# AUNTYPE           0
# AWKSTAT           0
# CAPGAIN           0
# GAPLOSS           0
# DIVVAL            0
# FILESTAT          0
# GRINREG           0
# GRINST            0
# HHDFMX            0
# HHDREL            0
# MARSUPWRT         0
# MIGMTR1           0
# MIGMTR3           0
# MIGMTR4           0
# MIGSAME           0
# MIGSUN            0
# NOEMP             0
# PARENT            0
# PEFNTVTY          0
# PEMNTVTY          0
# PENATVTY          0
# PRCITSHP          0
# SEOTR             0
# VETQVA            0
# VETYN             0
# WKSWORK           0
# AHRSPAY           0
# year              0
# income_bracket    0
# dtype: int64

# %%
dataset.shape
# Out:
# (199523, 42)

# %%
column_name = {
    'AAGE': 'Age',
    'ACLSWKR': 'Class_of_Worker',
    'ADTINK': 'Industry_Code',
    'ADTOCC': 'Occupation_Code',
    'AHGA': 'Education',
    'AHSCOL': 'Enrolled_in_Edu_Inst_Last_Week',
    'AMARITL': 'Marital_Status',
    'AMJIND': 'Industry',
    'AMJOCC': 'Occupation',
    'ARACE': 'Race',
    'PEMNTVTY': 'Country_of_Birth_Self',
    'PENATVTY': 'Country_of_Birth_Father',
    'PRCITSHP': 'Country_of_Birth_Mother',
    'SEOTR': 'Citizenship',
    'VETQVA': 'Own_Business_or_Self_Employed',
    'VETYN': 'Veteran_Benefits',
    'WKSWORK': 'Weeks_Worked_in_Year',
    'year': 'Year',
    'income_bracket': 'Income_Bracket'
}

# %%
df= dataset.rename(columns=column_name)

# %%
df
# Out:
#         Age                  Class_of_Worker  Industry_Code  Occupation_Code  \
# 0        73                  Not in universe              0                0
# 1        58   Self-employed-not incorporated              4               34
# 2        18                  Not in universe              0                0
# 3         9                  Not in universe              0                0
# 4        10                  Not in universe              0                0
# ...     ...                              ...            ...              ...
# 199518   87                  Not in universe              0                0
# 199519   65       Self-employed-incorporated             37                2
# 199520   47                  Not in universe              0                0
# 199521   16                  Not in universe              0                0
# 199522   32                          Private             42               30
#
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Income_Bracket', data=df)
plt.title('Income_Bracket vs Age')
plt.xlabel('Age')
plt.ylabel('Income_Bracket')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Race', y='Income_Bracket', data=df)
plt.title('Income_Bracket vs Race')
plt.xlabel('Race')
plt.ylabel('Income_Bracket')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Education', y='Income_Bracket', data=df)
plt.title('Income_Bracket vs Education')
plt.xlabel('Education')
plt.ylabel('Income_Bracket')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\91830\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Occupation_Code', y='Income_Bracket', data=df)
plt.title('Income_Bracket vs Occupation_Code')
plt.xlabel('Occupation_Code')
plt.ylabel('Income_Bracket')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Marital_Status', y='Income_Bracket', data=df)
plt.title('Income_Bracket vs Marital_Status')
plt.xlabel('Marital_Status')
plt.ylabel('Income_Bracket')
plt.xticks(rotation=45)
plt.show()
